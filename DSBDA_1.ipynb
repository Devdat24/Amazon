# %% [markdown]
# <a href="https://colab.research.google.com/github/Devdat24/Amazon/blob/main/DSBDA_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/weather_data.csv")

# %%
df
# Out:
#                      Formatted Date        Summary Precip Type  \
# 0     2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1     2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2     2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3     2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4     2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                             ...            ...         ...
# 5994  2006-05-15 19:00:00.000 +0200  Partly Cloudy        rain
# 5995  2006-05-15 20:00:00.000 +0200  Partly Cloudy        rain
# 5996  2006-05-15 21:00:00.000 +0200  Partly Cloudy        rain
# 5997  2006-05-15 22:00:00.000 +0200  Partly Cloudy        rain
# 5998  2006-05-15 23:00:00.000 +0200          Clear        rain
#
#       Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0            9.472222                  7.388889      0.89            14.1197
# ...

# %%
 df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# ...

# %%
df.tail()
# Out:
#                      Formatted Date        Summary Precip Type  \
# 5994  2006-05-15 19:00:00.000 +0200  Partly Cloudy        rain
# 5995  2006-05-15 20:00:00.000 +0200  Partly Cloudy        rain
# 5996  2006-05-15 21:00:00.000 +0200  Partly Cloudy        rain
# 5997  2006-05-15 22:00:00.000 +0200  Partly Cloudy        rain
# 5998  2006-05-15 23:00:00.000 +0200          Clear        rain
#
#       Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 5994        19.094444                 19.094444      0.60             6.9391
# 5995        17.655556                 17.655556      0.62             1.6100
# 5996        15.072222                 15.072222      0.78             1.9481
# 5997        13.405556                 13.405556      0.83             3.1073
# 5998        12.927778                 12.927778      0.90             2.7531
#
#       Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 5994                     350          11.2056           0
# ...

# %%
 df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# ...

# %%
df.sample()
# Out:
#                      Formatted Date Summary Precip Type  Temperature (C)  \
# 3599  2006-01-08 23:00:00.000 +0100   Clear        snow        -3.866667
#
#       Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 3599                 -3.866667      0.92             3.0912
#
#       Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 3599                     323           9.8049           0
#
#       Pressure (millibars)                    Daily Summary
# 3599               1036.45  Partly cloudy in the afternoon.

# %%
df.sample(5)
# Out:
#                      Formatted Date        Summary Precip Type  \
# 4967  2006-06-04 23:00:00.000 +0200  Mostly Cloudy        rain
# 4214  2006-07-31 14:00:00.000 +0200  Mostly Cloudy        rain
# 2758  2006-02-04 22:00:00.000 +0100       Overcast        snow
# 5731  2006-03-05 20:00:00.000 +0100       Overcast        snow
# 657   2006-04-07 09:00:00.000 +0200  Mostly Cloudy        rain
#
#       Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 4967        11.188889                 11.188889      0.93             6.5527
# 4214        31.077778                 30.777778      0.38             9.8532
# 2758        -3.461111                 -7.322222      0.82             9.6439
# 5731         0.000000                 -5.505556      0.92            22.0248
# 657          7.200000                  4.166667      0.65            17.3719
#
#       Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 4967                     283          14.0231           0
# ...

# %%
df.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)        int64
# Visibility (km)             float64
# Loud Cover                    int64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
df.isnull()
# Out:
#       Formatted Date  Summary  Precip Type  Temperature (C)  \
# 0              False    False        False            False
# 1              False    False        False            False
# 2              False    False        False            False
# 3              False    False        False            False
# 4              False    False        False            False
# ...              ...      ...          ...              ...
# 5994           False    False        False            False
# 5995           False    False        False            False
# 5996           False    False        False            False
# 5997           False    False        False            False
# 5998           False    False        False            False
#
#       Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                        False     False              False
# 1                        False     False              False
# 2                        False     False              False
# ...

# %%
df.isnull().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5994    False
# 5995    False
# 5996    False
# 5997    False
# 5998    False
# Length: 5999, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.rename(columns={'Temperature (C)':'Tmp (C)'},inplace=True)

# %%
df
# Out:
#                      Formatted Date        Summary Precip Type    Tmp (C)  \
# 0     2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain   9.472222
# 1     2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain   9.355556
# 2     2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain   9.377778
# 3     2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain   8.288889
# 4     2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain   8.755556
# ...                             ...            ...         ...        ...
# 5994  2006-05-15 19:00:00.000 +0200  Partly Cloudy        rain  19.094444
# 5995  2006-05-15 20:00:00.000 +0200  Partly Cloudy        rain  17.655556
# 5996  2006-05-15 21:00:00.000 +0200  Partly Cloudy        rain  15.072222
# 5997  2006-05-15 22:00:00.000 +0200  Partly Cloudy        rain  13.405556
# 5998  2006-05-15 23:00:00.000 +0200          Clear        rain  12.927778
#
#       Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
df.drop(columns=['Tmp (C)'],inplace=True)

# %%
df
# Out:
#                      Formatted Date        Summary Precip Type  \
# 0     2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1     2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2     2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3     2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4     2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                             ...            ...         ...
# 5994  2006-05-15 19:00:00.000 +0200  Partly Cloudy        rain
# 5995  2006-05-15 20:00:00.000 +0200  Partly Cloudy        rain
# 5996  2006-05-15 21:00:00.000 +0200  Partly Cloudy        rain
# 5997  2006-05-15 22:00:00.000 +0200  Partly Cloudy        rain
# 5998  2006-05-15 23:00:00.000 +0200          Clear        rain
#
#       Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                     7.388889      0.89            14.1197
# 1                     7.227778      0.86            14.2646
# ...
